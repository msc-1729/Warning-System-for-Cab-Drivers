# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random
from sklearn.utils import shuffle
from tensorflow.keras import datasets,layers,models
from tensorflow import keras as hehe
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
with open ("/content/drive/My Drive/trafficsigns/train.p",mode="rb") as training_data:
  train = pickle.load(training_data)
with open ("/content/drive/My Drive/trafficsigns/valid.p",mode="rb") as validation_data:
  valid = pickle.load(validation_data)
with open ("/content/drive/My Drive/trafficsigns/test.p",mode="rb") as testing_data:
  test = pickle.load(testing_data)

# %%
x_train , y_train = train['features'] , train['labels']
x_valid , y_valid = valid['features'] , valid['labels']
x_test , y_test = test['features'] , test['labels']

# %%
x_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
from sklearn.utils import shuffle
x_train , y_train = shuffle(x_train,y_train)
x_valid , y_valid = shuffle(x_valid,y_valid)
x_test , y_test = shuffle(x_test,y_test)

# %%
x_train_gray = np.sum(x_train/3 , axis=3 , keepdims = True)
x_valid_gray = np.sum(x_valid/3 , axis = 3 , keepdims = True)
x_test_gray = np.sum(x_test/3 , axis = 3 , keepdims =True)

# %%
x_train_gray_norm  = (x_train_gray - 128)/128
x_valid_gray_norm  = (x_valid_gray - 128)/128
x_test_gray_norm  = (x_test_gray - 128)/128

# %%
i = np.random.randint(1 , len(x_train_gray))
plt.imshow(x_train_gray[i].squeeze(),cmap='gray')
plt.figure()
plt.imshow(x_train[i])
plt.figure()
plt.imshow(x_train_gray_norm[i].squeeze() , cmap = 'gray')

# %%
w=5
l=5
fig,axes = plt.subplots(l,w,figsize=(10,10))
axes = axes.ravel()
n_training = len(x_train)
for i in np.arange(0 ,l*w):
  index = np.random.randint(0,n_training)
  axes[i].imshow(x_train[index])
  axes[i].set_title(y_train[index],fontsize = 15)
  axes[i].axis('off')
plt.subplots_adjust(hspace = 0.4)

# %%
from tensorflow.keras import datasets,layers,models
cnn = models.Sequential()
cnn.add(layers.Conv2D(16,(5,5),activation ='relu',input_shape=(32,32,1)))
cnn.add(layers.AveragePooling2D())
cnn.add(layers.Flatten())
cnn.add(layers.Dense(120 , activation = 'relu'))
cnn.add(layers.Dropout(0.5))
cnn.add(layers.Dense(98,activation = 'relu'))
cnn.add(layers.Dense(84 , activation  = 'relu'))
cnn.add(layers.Dense(43 , activation = 'softmax'))
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 16)        416
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 120)               376440
# _________________________________________________________________
# dropout (Dropout)            (None, 120)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 98)                11858
# _________________________________________________________________
# dense_2 (Dense)              (None, 84)                8316
# _________________________________________________________________
# dense_3 (Dense)              (None, 43)                3655
# =================================================================
# Total params: 400,685
# Trainable params: 400,685
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow import keras as hehe
opt = hehe.optimizers.Adam(learning_rate=0.01)
cnn.compile(optimizer = opt , loss = 'sparse_categorical_crossentropy' ,metrics = ['accuracy'])
history = cnn.fit(x_train_gray_norm,y_train,batch_size = 50 ,epochs=50,verbose=1,validation_data=(x_valid_gray_norm,y_valid))
# Out:
# Epoch 1/50
# 696/696 [==============================] - 17s 24ms/step - loss: 2.0833 - accuracy: 0.3912 - val_loss: 1.1821 - val_accuracy: 0.6152
# Epoch 2/50
# 696/696 [==============================] - 16s 24ms/step - loss: 1.4452 - accuracy: 0.5615 - val_loss: 1.0806 - val_accuracy: 0.6937
# Epoch 3/50
# 696/696 [==============================] - 16s 24ms/step - loss: 1.2499 - accuracy: 0.6214 - val_loss: 0.9496 - val_accuracy: 0.7347
# Epoch 4/50
# 696/696 [==============================] - 16s 23ms/step - loss: 1.2058 - accuracy: 0.6399 - val_loss: 0.9751 - val_accuracy: 0.7347
# Epoch 5/50
# 696/696 [==============================] - 16s 23ms/step - loss: 1.1316 - accuracy: 0.6657 - val_loss: 0.9027 - val_accuracy: 0.7397
# Epoch 6/50
# 696/696 [==============================] - 16s 23ms/step - loss: 1.1037 - accuracy: 0.6745 - val_loss: 0.8752 - val_accuracy: 0.7351
# Epoch 7/50
# 696/696 [==============================] - 16s 23ms/step - loss: 1.0828 - accuracy: 0.6825 - val_loss: 0.8028 - val_accuracy: 0.7871
# Epoch 8/50
# 696/696 [==============================] - 16s 23ms/step - loss: 1.0510 - accuracy: 0.6926 - val_loss: 1.1295 - val_accuracy: 0.7077
# Epoch 9/50
# 696/696 [==============================] - 16s 23ms/step - loss: 1.0621 - accuracy: 0.6954 - val_loss: 0.8031 - val_accuracy: 0.7937
# Epoch 10/50
# 696/696 [==============================] - 16s 23ms/step - loss: 1.0049 - accuracy: 0.7130 - val_loss: 0.8923 - val_accuracy: 0.7737
# Epoch 11/50
# 696/696 [==============================] - 16s 23ms/step - loss: 1.0776 - accuracy: 0.6942 - val_loss: 0.7350 - val_accuracy: 0.8079
# Epoch 12/50
# 696/696 [==============================] - 16s 23ms/step - loss: 1.0322 - accuracy: 0.7073 - val_loss: 0.9806 - val_accuracy: 0.7460
# Epoch 13/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9919 - accuracy: 0.7181 - val_loss: 0.9648 - val_accuracy: 0.7333
# Epoch 14/50
# 696/696 [==============================] - 16s 24ms/step - loss: 1.0331 - accuracy: 0.7089 - val_loss: 0.7917 - val_accuracy: 0.7980
# Epoch 15/50
# 696/696 [==============================] - 16s 24ms/step - loss: 1.0041 - accuracy: 0.7173 - val_loss: 0.8354 - val_accuracy: 0.7932
# Epoch 16/50
# 696/696 [==============================] - 16s 24ms/step - loss: 0.9526 - accuracy: 0.7305 - val_loss: 0.7569 - val_accuracy: 0.8107
# Epoch 17/50
# 696/696 [==============================] - 16s 23ms/step - loss: 1.0027 - accuracy: 0.7200 - val_loss: 1.1408 - val_accuracy: 0.7254
# Epoch 18/50
# 696/696 [==============================] - 16s 23ms/step - loss: 1.0464 - accuracy: 0.7130 - val_loss: 0.7781 - val_accuracy: 0.7864
# Epoch 19/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9750 - accuracy: 0.7276 - val_loss: 0.7630 - val_accuracy: 0.8061
# Epoch 20/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9657 - accuracy: 0.7302 - val_loss: 0.9546 - val_accuracy: 0.7707
# Epoch 21/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9642 - accuracy: 0.7315 - val_loss: 1.1298 - val_accuracy: 0.7281
# Epoch 22/50
# 696/696 [==============================] - 16s 23ms/step - loss: 1.0138 - accuracy: 0.7203 - val_loss: 0.8269 - val_accuracy: 0.7925
# Epoch 23/50
# 696/696 [==============================] - 16s 24ms/step - loss: 0.9594 - accuracy: 0.7344 - val_loss: 0.7592 - val_accuracy: 0.8202
# Epoch 24/50
# 696/696 [==============================] - 16s 24ms/step - loss: 0.9315 - accuracy: 0.7428 - val_loss: 0.7801 - val_accuracy: 0.8007
# Epoch 25/50
# 696/696 [==============================] - 16s 24ms/step - loss: 0.9656 - accuracy: 0.7338 - val_loss: 0.9975 - val_accuracy: 0.7689
# Epoch 26/50
# 696/696 [==============================] - 16s 24ms/step - loss: 0.9004 - accuracy: 0.7489 - val_loss: 0.7666 - val_accuracy: 0.8098
# Epoch 27/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9465 - accuracy: 0.7411 - val_loss: 0.7890 - val_accuracy: 0.8011
# Epoch 28/50
# 696/696 [==============================] - 17s 24ms/step - loss: 0.9526 - accuracy: 0.7403 - val_loss: 0.8970 - val_accuracy: 0.7934
# Epoch 29/50
# 696/696 [==============================] - 20s 28ms/step - loss: 0.9361 - accuracy: 0.7426 - val_loss: 0.7966 - val_accuracy: 0.8000
# Epoch 30/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9204 - accuracy: 0.7480 - val_loss: 1.0330 - val_accuracy: 0.7304
# Epoch 31/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9474 - accuracy: 0.7389 - val_loss: 0.9628 - val_accuracy: 0.7671
# Epoch 32/50
# 696/696 [==============================] - 17s 24ms/step - loss: 0.9118 - accuracy: 0.7526 - val_loss: 0.7927 - val_accuracy: 0.8005
# Epoch 33/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9698 - accuracy: 0.7363 - val_loss: 1.3180 - val_accuracy: 0.6669
# Epoch 34/50
# 696/696 [==============================] - 16s 24ms/step - loss: 0.9140 - accuracy: 0.7532 - val_loss: 0.9969 - val_accuracy: 0.7637
# Epoch 35/50
# 696/696 [==============================] - 16s 24ms/step - loss: 0.9121 - accuracy: 0.7530 - val_loss: 1.3022 - val_accuracy: 0.7016
# Epoch 36/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.8671 - accuracy: 0.7643 - val_loss: 0.8997 - val_accuracy: 0.7889
# Epoch 37/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9108 - accuracy: 0.7520 - val_loss: 0.9247 - val_accuracy: 0.7825
# Epoch 38/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9876 - accuracy: 0.7380 - val_loss: 1.0708 - val_accuracy: 0.7565
# Epoch 39/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9547 - accuracy: 0.7431 - val_loss: 0.7311 - val_accuracy: 0.8193
# Epoch 40/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.8686 - accuracy: 0.7637 - val_loss: 0.8123 - val_accuracy: 0.8159
# Epoch 41/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9520 - accuracy: 0.7463 - val_loss: 1.1439 - val_accuracy: 0.7465
# Epoch 42/50
# 696/696 [==============================] - 16s 23ms/step - loss: 1.0035 - accuracy: 0.7365 - val_loss: 0.9357 - val_accuracy: 0.7746
# Epoch 43/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9916 - accuracy: 0.7397 - val_loss: 0.7719 - val_accuracy: 0.8018
# Epoch 44/50
# 696/696 [==============================] - 17s 24ms/step - loss: 0.9173 - accuracy: 0.7532 - val_loss: 0.8105 - val_accuracy: 0.8082
# Epoch 45/50
# 696/696 [==============================] - 16s 24ms/step - loss: 0.9948 - accuracy: 0.7360 - val_loss: 1.2628 - val_accuracy: 0.7147
# Epoch 46/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9838 - accuracy: 0.7379 - val_loss: 0.7019 - val_accuracy: 0.8306
# Epoch 47/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9729 - accuracy: 0.7403 - val_loss: 0.8882 - val_accuracy: 0.7975
# Epoch 48/50
# 696/696 [==============================] - 16s 24ms/step - loss: 0.9463 - accuracy: 0.7477 - val_loss: 0.8883 - val_accuracy: 0.7968
# Epoch 49/50
# 696/696 [==============================] - 16s 23ms/step - loss: 0.9066 - accuracy: 0.7568 - val_loss: 0.9975 - val_accuracy: 0.7467
# Epoch 50/50
# 696/696 [==============================] - 16s 23ms/step - loss: 1.1518 - accuracy: 0.7014 - val_loss: 0.7695 - val_accuracy: 0.8111

# %%
history.history.keys()
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs =range(len(accuracy))
plt.plot(epochs,accuracy,'r',label = 'Train accuracy')
plt.plot(epochs ,val_accuracy , 'b',label ='valid accuracy')
plt.title('training accuracy vs valid accuracy')
# Out:
# Text(0.5, 1.0, 'training accuracy vs valid accuracy')

# %%
epochs =range(len(accuracy))
plt.plot(epochs,loss,'r',label = 'Training loss')
plt.plot(epochs ,val_loss , 'b',label ='validation loss')
plt.title('training loss vs validation loss')
# Out:
# Text(0.5, 1.0, 'training loss vs validation loss')

# %%
predicted_classes = cnn.predict_classes(x_test_gray_norm)
y_true = y_test
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true , predicted_classes)
plt.figure(figsize = (20,20))
sns.heatmap(cm,annot=True)

# %%
i=5
j=5
fig,axes2 = plt.subplots(i,j,figsize=(10,10))
axes2 = axes2.ravel()
for i in np.arange(0 , i*j):
  axes2[i].imshow(x_test[i])
  axes2[i].set_title('predicted = {}\n True = {}'.format(predicted_classes[i],y_true[i]))
plt.subplots_adjust(wspace = 1)

# %%
import pickle

# Save the trained model as a pickle string.
saved_model = pickle.dumps(cnn)

# Load the pickled model
knn_from_pickle = pickle.loads(saved_model)

# Use the loaded pickled model to make predictions
knn_from_pickle.predict(x_test)
